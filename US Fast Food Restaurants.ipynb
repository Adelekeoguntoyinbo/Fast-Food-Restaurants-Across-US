# %%
# importing the fast food restaurants population across US cities sample dataset from kaggle

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
data = pd.read_csv("C:\\Users\\Adeleke Oguntoyinbo\\Desktop\\FastFoodRestaurants.csv")
clean_data1 = data.replace("McDonalds","McDonald's")
clean_data2 =clean_data1.replace("Mcdonald's","McDonald's")
clean_data2.head()
# Out:
#                  address                    city country  \
# 0            324 Main St                 Massena      US
# 1        530 Clinton Ave  Washington Court House      US
# 2   408 Market Square Dr               Maysville      US
# 3  6098 State Highway 37                 Massena      US
# 4        139 Columbus Rd                  Athens      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# 2       us/ky/maysville/408marketsquaredr/1051460804  38.62736  -83.79141
# 3       us/ny/massena/6098statehighway37/-1161002137  44.95008  -74.84553
# 4               us/oh/athens/139columbusrd/990890980  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# ...

# %%
# top20 most visible resturants across US
top = clean_data2[["name"]].value_counts()
top2 = top.reset_index(name = "counts")
top20 = top2[0:20]
top20
# Out:
#                                      name  counts
# 0                              McDonald's    2082
# 1                             Burger King    1154
# 2                               Taco Bell     873
# 3                                 Wendy's     731
# 4                                  Arby's     518
# 5                                     KFC     421
# 6                          Domino's Pizza     345
# 7                                  Subway     322
# 8                          SONIC Drive In     226
# 9                                Hardee's     192
# 10                        Jack in the Box     187
# 11                           Jimmy John's     157
# 12                              Pizza Hut     128
# 13                         Sonic Drive-In     126
# 14  Bojangles' Famous Chicken 'n Biscuits     126
# 15                            Chick-fil-A     100
# 16                              Five Guys      96
# 17                            Dairy Queen      92
# ...

# %%
# top20 restaurants bar chart

Brand = top20["name"].to_list()
Counts = top20["counts"].to_list()
Brand.reverse()
Counts.reverse()
plt.barh(Brand,Counts,color="blue")
plt.xlabel("Amt of locations in US")
plt.title("top20 restaurants")
plt.show()

# %%
# grouping restuarants by US cities 1/2

Restbycities = clean_data.groupby(["city"])
No_of_rest_by_city = Restbycities[["name"]].value_counts()
rest_per_city=No_of_rest_by_city.reset_index(name = "counts")
rest_per_city
# Out:
#             city            name  counts
# 0      Abbeville  SONIC Drive In       1
# 1      Abbeville         Wendy's       1
# 2       Aberdeen      McDonald's       4
# 3       Aberdeen       Taco Bell       2
# 4       Aberdeen             KFC       2
# ...          ...             ...     ...
# 7974  Zanesville     Burger King       1
# 7975     Zebulon       Taco Bell       1
# 7976     Zebulon          Subway       1
# 7977        Zion     Burger King       1
# 7978  Zionsville     Burger King       1
#
# [7979 rows x 3 columns]

# %%
# grouping restuarants by US cities 2/2

a = rest_per_city.groupby(["city"])
b = a["counts"].sum()
ba = b.reset_index(name="Num_of_Rest.")
bb = ba.sort_values(by="Num_of_Rest.",ascending=False).reset_index(drop=True)
bb.head()
# Out:
#          city  Num_of_Rest.
# 0  Cincinnati           119
# 1   Las Vegas            72
# 2     Houston            63
# 3       Miami            58
# 4      Denver            52

# %%
# top 20 US cities with the most restaurants
a = bb[0:20].reset_index(drop=True)
a
# Out:
#              city  Num_of_Rest.
# 0      Cincinnati           119
# 1       Las Vegas            72
# 2         Houston            63
# 3           Miami            58
# 4          Denver            52
# 5         Chicago            51
# 6         Phoenix            42
# 7        Columbus            41
# 8         Atlanta            41
# 9   Oklahoma City            41
# 10      Lexington            37
# 11      Cleveland            37
# 12       New York            36
# 13     Washington            35
# 14    Albuquerque            35
# 15     Greenville            34
# 16       Columbia            34
# 17     Rapid City            34
# 18       Portland            34
# 19     Saint Paul            33

# %%
# top 20 US cities bar chart

x = a["city"].to_list()
y = a["Num_of_Rest."].to_list()

x.reverse()
y.reverse()

plt.barh(x,y,color="green")
plt.ylabel("City")
plt.xlabel("Num of restaurants")
plt.title("top 20 US cities with the most restuarants")
plt.show()
